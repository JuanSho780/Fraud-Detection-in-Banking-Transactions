# %%
import pandas as pd
import boto3
import json
from dotenv import load_dotenv
import time
import random
import os
from tenacity import retry, wait_exponential, stop_after_attempt, retry_if_exception_type
import botocore.exceptions
import re

# %%
def load():
    path = '../data/credit_data_with_descriptions.csv'
    data = pd.read_csv(path)
    
    print(data.info())

    return data

# %%
BATCH_SIZE = 50
MODEL_ID = "anthropic.claude-3-sonnet-20240229-v1:0"
REGION = 'sa-east-1'

# %%
def construir_prompt_en(batch):
    prompt = (
        "Below are profiles summaries of credit applicants. For each profile, generate a risk target (“bad risk” or “good risk”). "
        f"Return the targets numbered from 1 to {len(batch)}.\n\n"
    )
    for i, (_, row) in enumerate(batch.iterrows(), 1):
        prompt += (
            f"{i}.\n"
            f"Summary: {row['Description']}\n\n"
        )
    return prompt

# %%
# Crear cliente Bedrock
bedrock = boto3.client("bedrock-runtime", region_name=REGION)

# Función con retry automático para manejar throttling
@retry(
    wait=wait_exponential(multiplier=1, min=2, max=10),
    stop=stop_after_attempt(6),
    retry=retry_if_exception_type(botocore.exceptions.ClientError)
)
def obtener_respuesta(prompt):
    response = bedrock.invoke_model(
        modelId=MODEL_ID,
        contentType="application/json",
        accept="application/json",
        body=json.dumps({
            "messages": [
                {
                    "role": "user",
                    "content": prompt
                }
            ],
            "max_tokens": 800,
            "temperature": 0.7,
            "anthropic_version": "bedrock-2023-05-31"
        })
    )
    result = json.loads(response['body'].read())
    return result['content'][0]['text']

# %%
def main(chunk_size=5):
    load_dotenv()
    df = load()
    targets = []

    for i in range(0, len(df), chunk_size):
        batch = df.iloc[i:i+chunk_size]
        prompt = construir_prompt_en(batch)
        print(f"Procesando filas {i + 1} a {i + len(batch)}...")

        try:
            respuesta = obtener_respuesta(prompt)
            print(respuesta)

            descripciones_batch = [
                re.sub(r"^\d+\.\s*", "", line.strip())  # quita "1. " y deja "Good risk"
                for line in respuesta.strip().split("\n")
                if re.match(r"^\d+\.\s*", line.strip())  # solo líneas que empiezan con número
            ]

            if len(descripciones_batch) != len(batch):
                raise ValueError(f"Se esperaban {len(batch)} descripciones pero se obtuvieron {len(descripciones_batch)}")

            targets.extend(descripciones_batch)

        except Exception as e:
            print(f"Error en lote {i}–{i+chunk_size}: {e}")
            targets.extend(["ERROR"] * len(batch))

        time.sleep(2)  # descanso entre lotes para evitar throttling

    df["Risk target"] = targets
    df.to_csv("credit_data_with_targets.csv", index=False)
    print("Archivo exportado TOTALMENTE")

# %%
main(50)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               1000 non-null   int64
#  1   Sex               1000 non-null   object
#  2   Job               1000 non-null   int64
#  3   Housing           1000 non-null   object
#  4   Saving accounts   1000 non-null   object
#  5   Checking account  1000 non-null   object
#  6   Credit amount     1000 non-null   int64
#  7   Duration          1000 non-null   int64
#  8   Purpose           1000 non-null   object
#  9   Description       1000 non-null   object
# dtypes: int64(4), object(6)
# memory usage: 78.3+ KB
# None
# Procesando filas 1 a 50...
# 1. Good risk
# 2. Bad risk
# 3. Good risk
# 4. Bad risk
# 5. Bad risk
# 6. Bad risk
# 7. Good risk
# 8. Good risk
# 9. Good risk
# 10. Good risk
# 11. Good risk
# 12. Bad risk
# 13. Good risk
# 14. Bad risk
# 15. Bad risk
# 16. Good risk
# 17. Good risk
# 18. Bad risk
# 19. Bad risk
# 20. Good risk
# 21. Good risk
# 22. Good risk
# 23. Bad risk
# 24. Good risk
# 25. Good risk
# 26. Bad risk
# 27. Good risk
# 28. Good risk
# 29. Bad risk
# 30. Bad risk
# 31. Good risk
# 32. Bad risk
# 33. Good risk
# 34. Bad risk
# 35. Good risk
# 36. Bad risk
# 37. Bad risk
# 38. Good risk
# 39. Good risk
# 40. Good risk
# 41. Good risk
# 42. Good risk
# 43. Bad risk
# 44. Bad risk
# 45. Bad risk
# 46. Good risk
# 47. Good risk
# 48. Bad risk
# 49. Bad risk
# 50. Good risk
# Procesando filas 51 a 100...
# Here are the risk targets for the 50 credit applicant profiles, numbered from 1 to 50:
#
# 1. Good risk
# 2. Good risk
# 3. Good risk
# 4. Good risk
# 5. Good risk
# 6. Good risk
# 7. Good risk
# 8. Bad risk
# 9. Good risk
# 10. Bad risk
# 11. Good risk
# 12. Good risk
# 13. Good risk
# 14. Bad risk
# 15. Good risk
# 16. Good risk
# 17. Good risk
# 18. Good risk
# 19. Good risk
# 20. Good risk
# 21. Bad risk
# 22. Good risk
# 23. Bad risk
# 24. Bad risk
# 25. Bad risk
# 26. Bad risk
# 27. Bad risk
# 28. Bad risk
# 29. Bad risk
# 30. Good risk
# 31. Good risk
# 32. Good risk
# 33. Good risk
# 34. Bad risk
# 35. Bad risk
# 36. Good risk
# 37. Good risk
# 38. Bad risk
# 39. Good risk
# 40. Good risk
# 41. Good risk
# 42. Good risk
# 43. Good risk
# 44. Bad risk
# 45. Good risk
# 46. Bad risk
# 47. Good risk
# 48. Good risk
# 49. Good risk
# 50. Bad risk
# Procesando filas 101 a 150...
# Here are the risk targets for the 50 credit applicant profiles, numbered from 1 to 50:
#
# 1. Good risk
# 2. Good risk
# 3. Good risk
# 4. Good risk
# 5. Bad risk
# 6. Bad risk
# 7. Good risk
# 8. Bad risk
# 9. Bad risk
# 10. Good risk
# 11. Good risk
# 12. Good risk
# 13. Bad risk
# 14. Bad risk
# 15. Good risk
# 16. Bad risk
# 17. Bad risk
# 18. Good risk
# 19. Good risk
# 20. Good risk
# 21. Good risk
# 22. Good risk
# 23. Good risk
# 24. Good risk
# 25. Good risk
# 26. Good risk
# 27. Good risk
# 28. Good risk
# 29. Good risk
# 30. Good risk
# 31. Bad risk
# 32. Bad risk
# 33. Good risk
# 34. Good risk
# 35. Bad risk
# 36. Good risk
# 37. Good risk
# 38. Good risk
# 39. Good risk
# 40. Good risk
# 41. Good risk
# 42. Good risk
# 43. Good risk
# 44. Good risk
# 45. Good risk
# 46. Good risk
# 47. Good risk
# 48. Good risk
# 49. Bad risk
# 50. Good risk
# Procesando filas 151 a 200...
# Here are the risk targets for each credit applicant profile, numbered from 1 to 50:
#
# 1. Good risk
# 2. Bad risk
# 3. Bad risk
# 4. Good risk
# 5. Good risk
# 6. Bad risk
# 7. Good risk
# 8. Good risk
# 9. Good risk
# 10. Bad risk
# 11. Good risk
# 12. Good risk
# 13. Good risk
# 14. Bad risk
# 15. Good risk
# 16. Good risk
# 17. Bad risk
# 18. Good risk
# 19. Bad risk
# 20. Bad risk
# 21. Bad risk
# 22. Good risk
# 23. Good risk
# 24. Good risk
# 25. Bad risk
# 26. Good risk
# 27. Bad risk
# 28. Good risk
# 29. Bad risk
# 30. Bad risk
# 31. Bad risk
# 32. Good risk
# 33. Bad risk
# 34. Good risk
# 35. Good risk
# 36. Good risk
# 37. Good risk
# 38. Bad risk
# 39. Good risk
# 40. Good risk
# 41. Good risk
# 42. Bad risk
# 43. Bad risk
# 44. Bad risk
# 45. Bad risk
# 46. Good risk
# 47. Bad risk
# 48. Good risk
# 49. Bad risk
# 50. Bad risk
# Procesando filas 201 a 250...
# 1. Good risk
# 2. Good risk
# 3. Bad risk
# 4. Good risk
# 5. Good risk
# 6. Bad risk
# 7. Good risk
# 8. Good risk
# 9. Bad risk
# 10. Good risk
# 11. Good risk
# 12. Bad risk
# 13. Bad risk
# 14. Bad risk
# 15. Bad risk
# 16. Good risk
# 17. Bad risk
# 18. Bad risk
# 19. Bad risk
# 20. Good risk
# 21. Good risk
# 22. Good risk
# 23. Good risk
# 24. Bad risk
# 25. Bad risk
# 26. Good risk
# 27. Bad risk
# 28. Bad risk
# 29. Good risk
# 30. Bad risk
# 31. Bad risk
# 32. Good risk
# 33. Good risk
# 34. Good risk
# 35. Good risk
# 36. Good risk
# 37. Bad risk
# 38. Bad risk
# 39. Good risk
# 40. Bad risk
# 41. Good risk
# 42. Good risk
# 43. Bad risk
# 44. Good risk
# 45. Good risk
# 46. Good risk
# 47. Good risk
# 48. Good risk
# 49. Good risk
# 50. Good risk
# Procesando filas 251 a 300...
# Here are the risk targets for the 50 credit applicant profiles:
#
# 1. Good risk
# 2. Good risk
# 3. Good risk
# 4. Good risk
# 5. Good risk
# 6. Bad risk
# 7. Bad risk
# 8. Bad risk
# 9. Good risk
# 10. Good risk
# 11. Bad risk
# 12. Bad risk
# 13. Bad risk
# 14. Bad risk
# 15. Bad risk
# 16. Good risk
# 17. Bad risk
# 18. Bad risk
# 19. Bad risk
# 20. Good risk
# 21. Good risk
# 22. Good risk
# 23. Bad risk
# 24. Bad risk
# 25. Bad risk
# 26. Bad risk
# 27. Bad risk
# 28. Bad risk
# 29. Bad risk
# 30. Good risk
# 31. Good risk
# 32. Good risk
# 33. Bad risk
# 34. Good risk
# 35. Good risk
# 36. Bad risk
# 37. Bad risk
# 38. Bad risk
# 39. Good risk
# 40. Bad risk
# 41. Good risk
# 42. Bad risk
# 43. Bad risk
# 44. Bad risk
# 45. Bad risk
# 46. Bad risk
# 47. Bad risk
# 48. Bad risk
# 49. Bad risk
# 50. Good risk
# Procesando filas 301 a 350...
# Here are the risk targets for the 50 credit applicant profiles, numbered from 1 to 50:
#
# 1. Good risk
# 2. Good risk
# 3. Good risk
# 4. Good risk
# 5. Bad risk
# 6. Good risk
# 7. Bad risk
# 8. Good risk
# 9. Good risk
# 10. Bad risk
# 11. Bad risk
# 12. Good risk
# 13. Good risk
# 14. Good risk
# 15. Good risk
# 16. Good risk
# 17. Good risk
# 18. Good risk
# 19. Good risk
# 20. Good risk
# 21. Good risk
# 22. Good risk
# 23. Good risk
# 24. Good risk
# 25. Good risk
# 26. Good risk
# 27. Bad risk
# 28. Good risk
# 29. Bad risk
# 30. Good risk
# 31. Good risk
# 32. Good risk
# 33. Bad risk
# 34. Bad risk
# 35. Bad risk
# 36. Bad risk
# 37. Bad risk
# 38. Bad risk
# 39. Good risk
# 40. Good risk
# 41. Bad risk
# 42. Bad risk
# 43. Good risk
# 44. Good risk
# 45. Good risk
# 46. Good risk
# 47. Good risk
# 48. Bad risk
# 49. Good risk
# 50. Good risk
# Procesando filas 351 a 400...
# Here are the risk targets for the 50 credit applicant profiles:
#
# 1. Good risk
# 2. Good risk
# 3. Good risk
# 4. Bad risk
# 5. Good risk
# 6. Good risk
# 7. Good risk
# 8. Bad risk
# 9. Good risk
# 10. Bad risk
# 11. Good risk
# 12. Good risk
# 13. Good risk
# 14. Bad risk
# 15. Bad risk
# 16. Good risk
# 17. Good risk
# 18. Bad risk
# 19. Bad risk
# 20. Good risk
# 21. Good risk
# 22. Bad risk
# 23. Good risk
# 24. Bad risk
# 25. Bad risk
# 26. Bad risk
# 27. Good risk
# 28. Good risk
# 29. Bad risk
# 30. Good risk
# 31. Good risk
# 32. Bad risk
# 33. Bad risk
# 34. Good risk
# 35. Good risk
# 36. Good risk
# 37. Bad risk
# 38. Good risk
# 39. Good risk
# 40. Good risk
# 41. Good risk
# 42. Good risk
# 43. Bad risk
# 44. Bad risk
# 45. Good risk
# 46. Good risk
# 47. Good risk
# 48. Good risk
# 49. Good risk
# 50. Good risk
# Procesando filas 401 a 450...
# Here are the risk targets for the 50 credit applicant profiles:
#
# 1. Good risk
# 2. Bad risk
# 3. Bad risk
# 4. Good risk
# 5. Good risk
# 6. Good risk
# 7. Good risk
# 8. Good risk
# 9. Good risk
# 10. Good risk
# 11. Bad risk
# 12. Good risk
# 13. Good risk
# 14. Good risk
# 15. Bad risk
# 16. Good risk
# 17. Bad risk
# 18. Bad risk
# 19. Good risk
# 20. Good risk
# 21. Good risk
# 22. Good risk
# 23. Bad risk
# 24. Good risk
# 25. Good risk
# 26. Bad risk
# 27. Bad risk
# 28. Good risk
# 29. Good risk
# 30. Bad risk
# 31. Bad risk
# 32. Bad risk
# 33. Bad risk
# 34. Good risk
# 35. Bad risk
# 36. Good risk
# 37. Good risk
# 38. Good risk
# 39. Bad risk
# 40. Bad risk
# 41. Good risk
# 42. Bad risk
# 43. Bad risk
# 44. Bad risk
# 45. Bad risk
# 46. Bad risk
# 47. Bad risk
# 48. Bad risk
# 49. Good risk
# 50. Good risk
# Procesando filas 451 a 500...
# Here are the risk targets for the 50 credit applicant profiles:
#
# 1. Bad risk
# 2. Good risk
# 3. Bad risk
# 4. Good risk
# 5. Bad risk
# 6. Good risk
# 7. Bad risk
# 8. Bad risk
# 9. Good risk
# 10. Good risk
# 11. Bad risk
# 12. Good risk
# 13. Good risk
# 14. Good risk
# 15. Good risk
# 16. Bad risk
# 17. Bad risk
# 18. Bad risk
# 19. Good risk
# 20. Bad risk
# 21. Good risk
# 22. Bad risk
# 23. Bad risk
# 24. Good risk
# 25. Good risk
# 26. Bad risk
# 27. Good risk
# 28. Good risk
# 29. Good risk
# 30. Bad risk
# 31. Good risk
# 32. Good risk
# 33. Good risk
# 34. Good risk
# 35. Good risk
# 36. Good risk
# 37. Bad risk
# 38. Bad risk
# 39. Good risk
# 40. Bad risk
# 41. Good risk
# 42. Bad risk
# 43. Good risk
# 44. Good risk
# 45. Bad risk
# 46. Bad risk
# 47. Good risk
# 48. Bad risk
# 49. Bad risk
# 50. Good risk
# Procesando filas 501 a 550...
# Here are the risk targets for the 50 credit applicant profiles, numbered from 1 to 50:
#
# 1. Bad risk
# 2. Bad risk
# 3. Good risk
# 4. Good risk
# 5. Bad risk
# 6. Good risk
# 7. Good risk
# 8. Good risk
# 9. Good risk
# 10. Bad risk
# 11. Good risk
# 12. Bad risk
# 13. Bad risk
# 14. Good risk
# 15. Bad risk
# 16. Good risk
# 17. Bad risk
# 18. Bad risk
# 19. Good risk
# 20. Good risk
# 21. Bad risk
# 22. Bad risk
# 23. Bad risk
# 24. Good risk
# 25. Bad risk
# 26. Bad risk
# 27. Good risk
# 28. Good risk
# 29. Bad risk
# 30. Good risk
# 31. Bad risk
# 32. Good risk
# 33. Bad risk
# 34. Good risk
# 35. Bad risk
# 36. Bad risk
# 37. Good risk
# 38. Bad risk
# 39. Bad risk
# 40. Bad risk
# 41. Bad risk
# 42. Bad risk
# 43. Bad risk
# 44. Bad risk
# 45. Good risk
# 46. Bad risk
# 47. Good risk
# 48. Good risk
# 49. Good risk
# 50. Bad risk
# Procesando filas 551 a 600...
# Here are the risk targets for the 50 credit applicant profiles, numbered from 1 to 50:
#
# 1. Good risk
# 2. Good risk
# 3. Bad risk
# 4. Good risk
# 5. Good risk
# 6. Good risk
# 7. Good risk
# 8. Bad risk
# 9. Bad risk
# 10. Good risk
# 11. Bad risk
# 12. Bad risk
# 13. Good risk
# 14. Bad risk
# 15. Good risk
# 16. Good risk
# 17. Good risk
# 18. Good risk
# 19. Bad risk
# 20. Bad risk
# 21. Bad risk
# 22. Bad risk
# 23. Bad risk
# 24. Bad risk
# 25. Good risk
# 26. Good risk
# 27. Good risk
# 28. Good risk
# 29. Good risk
# 30. Good risk
# 31. Good risk
# 32. Bad risk
# 33. Good risk
# 34. Bad risk
# 35. Bad risk
# 36. Bad risk
# 37. Good risk
# 38. Bad risk
# 39. Good risk
# 40. Bad risk
# 41. Good risk
# 42. Good risk
# 43. Good risk
# 44. Bad risk
# 45. Good risk
# 46. Good risk
# 47. Good risk
# 48. Bad risk
# 49. Good risk
# 50. Bad risk
# Procesando filas 601 a 650...
# Here are the risk targets for the 50 credit applicant profiles, numbered from 1 to 50:
#
# 1. Good risk
# 2. Good risk
# 3. Moderate risk
# 4. Good risk
# 5. Good risk
# 6. Good risk
# 7. Moderate risk
# 8. Good risk
# 9. Good risk
# 10. Good risk
# 11. Good risk
# 12. Moderate risk
# 13. Moderate risk
# 14. Bad risk
# 15. Moderate risk
# 16. Bad risk
# 17. Bad risk
# 18. Bad risk
# 19. Moderate risk
# 20. Moderate risk
# 21. Moderate risk
# 22. Good risk
# 23. Moderate risk
# 24. Moderate risk
# 25. Moderate risk
# 26. Good risk
# 27. Good risk
# 28. Good risk
# 29. Good risk
# 30. Moderate risk
# 31. Moderate risk
# 32. Moderate risk
# 33. Good risk
# 34. Moderate risk
# 35. Moderate risk
# 36. Good risk
# 37. Good risk
# 38. Bad risk
# 39. Good risk
# 40. Bad risk
# 41. Moderate risk
# 42. Moderate risk
# 43. Good risk
# 44. Moderate risk
# 45. Moderate risk
# 46. Bad risk
# 47. Moderate risk
# 48. Good risk
# 49. Good risk
# 50. Moderate risk
# Procesando filas 651 a 700...
# Here are the risk targets for the 50 credit applicant profiles, numbered from 1 to 50:
#
# 1. Good risk
# 2. Good risk
# 3. Bad risk
# 4. Good risk
# 5. Bad risk
# 6. Bad risk
# 7. Good risk
# 8. Bad risk
# 9. Good risk
# 10. Good risk
# 11. Good risk
# 12. Bad risk
# 13. Good risk
# 14. Good risk
# 15. Good risk
# 16. Bad risk
# 17. Good risk
# 18. Good risk
# 19. Bad risk
# 20. Good risk
# 21. Good risk
# 22. Good risk
# 23. Good risk
# 24. Good risk
# 25. Good risk
# 26. Bad risk
# 27. Good risk
# 28. Good risk
# 29. Bad risk
# 30. Good risk
# 31. Good risk
# 32. Good risk
# 33. Good risk
# 34. Good risk
# 35. Bad risk
# 36. Bad risk
# 37. Good risk
# 38. Good risk
# 39. Good risk
# 40. Good risk
# 41. Bad risk
# 42. Good risk
# 43. Good risk
# 44. Bad risk
# 45. Good risk
# 46. Good risk
# 47. Good risk
# 48. Good risk
# 49. Good risk
# 50. Good risk
# Procesando filas 701 a 750...
# Here are the risk targets for the 50 credit applicant profiles:
#
# 1. Good risk
# 2. Bad risk
# 3. Good risk
# 4. Good risk
# 5. Bad risk
# 6. Good risk
# 7. Bad risk
# 8. Bad risk
# 9. Bad risk
# 10. Bad risk
# 11. Good risk
# 12. Bad risk
# 13. Bad risk
# 14. Bad risk
# 15. Bad risk
# 16. Good risk
# 17. Good risk
# 18. Bad risk
# 19. Good risk
# 20. Good risk
# 21. Good risk
# 22. Good risk
# 23. Bad risk
# 24. Good risk
# 25. Bad risk
# 26. Good risk
# 27. Good risk
# 28. Bad risk
# 29. Bad risk
# 30. Good risk
# 31. Bad risk
# 32. Bad risk
# 33. Bad risk
# 34. Good risk
# 35. Bad risk
# 36. Bad risk
# 37. Bad risk
# 38. Bad risk
# 39. Bad risk
# 40. Good risk
# 41. Bad risk
# 42. Bad risk
# 43. Bad risk
# 44. Good risk
# 45. Bad risk
# 46. Bad risk
# 47. Bad risk
# 48. Bad risk
# 49. Bad risk
# 50. Bad risk
# Procesando filas 751 a 800...
# Here are the risk targets for the 50 credit applicant profiles:
#
# 1. Good risk
# 2. Bad risk
# 3. Moderate risk
# 4. Bad risk
# 5. Good risk
# 6. Moderate risk
# 7. Moderate risk
# 8. Moderate risk
# 9. Moderate risk
# 10. Moderate risk
# 11. Bad risk
# 12. Bad risk
# 13. Bad risk
# 14. Good risk
# 15. Good risk
# 16. Moderate risk
# 17. Bad risk
# 18. Good risk
# 19. Good risk
# 20. Moderate risk
# 21. Bad risk
# 22. Good risk
# 23. Good risk
# 24. Good risk
# 25. Good risk
# 26. Bad risk
# 27. Good risk
# 28. Bad risk
# 29. Good risk
# 30. Good risk
# 31. Bad risk
# 32. Good risk
# 33. Moderate risk
# 34. Moderate risk
# 35. Good risk
# 36. Good risk
# 37. Good risk
# 38. Moderate risk
# 39. Moderate risk
# 40. Bad risk
# 41. Moderate risk
# 42. Good risk
# 43. Moderate risk
# 44. Moderate risk
# 45. Good risk
# 46. Moderate risk
# 47. Bad risk
# 48. Bad risk
# 49. Moderate risk
# 50. Moderate risk
# Procesando filas 801 a 850...
# Here are the risk targets for the 50 credit applicant profiles:
#
# 1. Good risk
# 2. Bad risk
# 3. Bad risk
# 4. Good risk
# 5. Bad risk
# 6. Bad risk
# 7. Good risk
# 8. Good risk
# 9. Bad risk
# 10. Bad risk
# 11. Good risk
# 12. Good risk
# 13. Bad risk
# 14. Bad risk
# 15. Bad risk
# 16. Bad risk
# 17. Good risk
# 18. Good risk
# 19. Bad risk
# 20. Good risk
# 21. Good risk
# 22. Good risk
# 23. Bad risk
# 24. Good risk
# 25. Good risk
# 26. Bad risk
# 27. Bad risk
# 28. Bad risk
# 29. Bad risk
# 30. Bad risk
# 31. Good risk
# 32. Good risk
# 33. Bad risk
# 34. Bad risk
# 35. Good risk
# 36. Good risk
# 37. Good risk
# 38. Good risk
# 39. Bad risk
# 40. Bad risk
# 41. Bad risk
# 42. Good risk
# 43. Good risk
# 44. Good risk
# 45. Good risk
# 46. Good risk
# 47. Bad risk
# 48. Good risk
# 49. Good risk
# 50. Good risk
# Procesando filas 851 a 900...
# Here are the risk targets for the 50 credit applicant profiles:
#
# 1. Bad risk
# 2. Bad risk
# 3. Bad risk
# 4. Bad risk
# 5. Good risk
# 6. Good risk
# 7. Good risk
# 8. Bad risk
# 9. Bad risk
# 10. Bad risk
# 11. Good risk
# 12. Bad risk
# 13. Bad risk
# 14. Good risk
# 15. Bad risk
# 16. Good risk
# 17. Bad risk
# 18. Bad risk
# 19. Good risk
# 20. Bad risk
# 21. Good risk
# 22. Good risk
# 23. Bad risk
# 24. Bad risk
# 25. Bad risk
# 26. Good risk
# 27. Bad risk
# 28. Bad risk
# 29. Bad risk
# 30. Bad risk
# 31. Good risk
# 32. Good risk
# 33. Bad risk
# 34. Bad risk
# 35. Bad risk
# 36. Bad risk
# 37. Good risk
# 38. Good risk
# 39. Good risk
# 40. Good risk
# 41. Good risk
# 42. Bad risk
# 43. Bad risk
# 44. Good risk
# 45. Bad risk
# 46. Good risk
# 47. Bad risk
# 48. Good risk
# 49. Bad risk
# 50. Bad risk
# Procesando filas 901 a 950...
# Here are the risk targets numbered from 1 to 50:
#
# 1. Good risk
# 2. Good risk
# 3. Bad risk
# 4. Good risk
# 5. Good risk
# 6. Good risk
# 7. Bad risk
# 8. Good risk
# 9. Bad risk
# 10. Bad risk
# 11. Bad risk
# 12. Bad risk
# 13. Good risk
# 14. Good risk
# 15. Good risk
# 16. Bad risk
# 17. Good risk
# 18. Bad risk
# 19. Good risk
# 20. Good risk
# 21. Good risk
# 22. Bad risk
# 23. Good risk
# 24. Good risk
# 25. Bad risk
# 26. Good risk
# 27. Good risk
# 28. Bad risk
# 29. Good risk
# 30. Good risk
# 31. Bad risk
# 32. Good risk
# 33. Good risk
# 34. Good risk
# 35. Good risk
# 36. Good risk
# 37. Good risk
# 38. Good risk
# 39. Bad risk
# 40. Bad risk
# 41. Good risk
# 42. Good risk
# 43. Good risk
# 44. Bad risk
# 45. Good risk
# 46. Bad risk
# 47. Good risk
# 48. Good risk
# 49. Good risk
# 50. Good risk
# Procesando filas 951 a 1000...
# Here are the risk targets for the 50 credit applicant profiles, numbered from 1 to 50:
#
# 1. Good risk
# 2. Good risk
# 3. Good risk
# 4. Bad risk
# 5. Good risk
# 6. Good risk
# 7. Bad risk
# 8. Good risk
# 9. Bad risk
# 10. Good risk
# 11. Good risk
# 12. Good risk
# 13. Good risk
# 14. Good risk
# 15. Good risk
# 16. Good risk
# 17. Good risk
# 18. Bad risk
# 19. Bad risk
# 20. Bad risk
# 21. Good risk
# 22. Bad risk
# 23. Bad risk
# 24. Bad risk
# 25. Good risk
# 26. Good risk
# 27. Good risk
# 28. Bad risk
# 29. Bad risk
# 30. Bad risk
# 31. Bad risk
# 32. Bad risk
# 33. Good risk
# 34. Bad risk
# 35. Good risk
# 36. Bad risk
# 37. Bad risk
# 38. Good risk
# 39. Bad risk
# 40. Good risk
# 41. Good risk
# 42. Good risk
# 43. Bad risk
# 44. Bad risk
# 45. Good risk
# 46. Good risk
# 47. Bad risk
# 48. Good risk
# 49. Bad risk
# 50. Bad risk
# Archivo exportado TOTALMENTE
